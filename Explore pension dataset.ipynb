# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pensions = pd.read_csv("~/Documents/Thinkful/Unit4/PPD_PlanLevel.csv.zip", compression = 'zip')
# Out:
# /usr/local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (5,111) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pensions.head()
# Out:
#    ppd_id     PlanName    fy  system_id  \
# 0       1  Alabama ERS  2001        1.0
# 1       1  Alabama ERS  2002        1.0
# 2       1  Alabama ERS  2003        1.0
# 3       1  Alabama ERS  2004        1.0
# 4       1  Alabama ERS  2005        1.0
#
#                               PlanFullName source_PlanBasics  InPFS  \
# 0  Employees’ Retirement System of Alabama               NaN    1.0
# 1  Employees’ Retirement System of Alabama               NaN    1.0
# 2  Employees’ Retirement System of Alabama               NaN    1.0
# 3  Employees’ Retirement System of Alabama               NaN    1.0
# 4  Employees’ Retirement System of Alabama               NaN    1.0
#
#    FiscalYearType  PlanInceptionYear  PlanClosed  ...  HFTotal_Trgt  \
# 0             1.0             1945.0         0.0  ...           NaN
# 1             1.0             1945.0         0.0  ...           NaN
# 2             1.0             1945.0         0.0  ...           NaN
# 3             1.0             1945.0         0.0  ...           NaN
# 4             1.0             1945.0         0.0  ...           NaN
#
#    COMDTotal_Rtrn  COMDTotal_Actl COMDTotal_Trgt CashTotal_Rtrn  \
# 0             NaN             NaN            NaN            NaN
# 1             NaN             NaN            NaN            NaN
# 2             NaN             NaN            NaN            NaN
# 3             NaN             NaN            NaN            NaN
# 4             NaN             NaN            NaN            NaN
#
#   CashTotal_Actl  CashTotal_Trgt OtherTotal_Rtrn  OtherTotal_Actl  \
# 0            NaN             NaN             NaN              NaN
# 1            NaN             NaN             NaN              NaN
# 2            NaN             NaN             NaN              NaN
# 3            NaN             NaN             NaN              NaN
# 4            NaN             NaN             NaN              NaN
#
#   OtherTotal_Trgt
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 269 columns]

# %%
pensions.PlanName.value_counts()
# Out:
# Denver Employees                            17
# Florida RS                                  17
# Rhode Island ERS                            17
# Washington Teachers Plan 2/3                17
# Chicago Municipal                           17
# Indiana PERF                                17
# Washington PERS 2/3                         17
# New Mexico PERA                             17
# Kentucky ERS                                17
# Minnesota State Employees                   17
# Colorado State                              17
# Missouri DOT and Highway                    17
# Illinois Universities                       17
# Louisiana State Parochial Employees         17
# North Carolina Local Government             17
# South Carolina Police                       17
# San Diego City ERS                          17
# Maine State and Teacher                     17
# New York City Fire                          17
# Alameda County ERS                          17
# Hartford MERF                               17
# Pennsylvania School Employees               17
# Missouri State Employees                    17
# TN Political Subdivisions                   17
# Lexington-Fayette County Police and Fire    17
# Wisconsin RS                                17
# Atlanta Police                              17
# Alaska PERS                                 17
# North Dakota Teachers                       17
# Baton Rouge City Parish RS                  17
#                                             ..
# Massachusetts Teachers                      17
# Oklahoma City ERS                           17
# Connecticut SERS                            17
# Atlanta ERS                                 17
# New York City Teachers                      17
# Texas Teachers                              17
# Iowa PERS                                   17
# Delaware State Employees                    17
# Minneapolis ERF                             17
# Pittsburgh Police                           17
# Maine Local                                 17
# Oklahoma Teachers                           17
# New York State Teachers                     17
# Arizona Public Safety                       17
# Omaha Police and Fire                       17
# Rhode Island Municipal                      17
# Wyoming Public Employees                    17
# Minnesota Police and Fire                   17
# Maryland Teachers                           17
# Louisiana Teachers                          17
# Birmingham RRS                              17
# New Orleans ERS                             17
# Nashville-Davidson ERS                      17
# Kentucky Teachers                           17
# Wichita ERS                                 17
# Washington School Employees Plan 2/3        17
# Connecticut Municipal                       17
# Michigan SERS                               17
# Duluth Teachers                             14
# Colorado State and School                    4
# Name: PlanName, Length: 180, dtype: int64

# %%
pensions.StateAbbrev.value_counts()
# Out:
# CA    255
# IL    136
# TX    136
# MO    119
# NY    119
# LA    119
# MN    113
# PA     85
# WA     85
# OH     85
# AZ     85
# MI     85
# CO     81
# OK     68
# CT     68
# KY     68
# MD     68
# GA     68
# AL     51
# NC     51
# MA     51
# RI     51
# NJ     51
# WI     51
# FL     51
# VA     51
# TN     51
# NE     51
# AK     51
# UT     34
# NM     34
# KS     34
# IA     34
# AR     34
# MT     34
# WV     34
# NV     34
# DE     34
# ME     34
# VT     34
# IN     34
# DC     34
# SC     34
# ND     34
# ID     17
# SD     17
# NH     17
# HI     17
# MS     17
# OR     17
# WY     17
# Name: StateAbbrev, dtype: int64

# %%
len(pensions.StateAbbrev.value_counts())
# Out:
# 51

# %%
pensions.StateName.value_counts()
# Out:
# California              255
# Texas                   136
# Illinois                136
# Missouri                119
# New York                119
# Louisiana               119
# Minnesota               113
# Pennsylvania             85
# Michigan                 85
# Ohio                     85
# Washington               85
# Arizona                  85
# Colorado                 81
# Connecticut              68
# Georgia                  68
# Maryland                 68
# Oklahoma                 68
# Kentucky                 68
# Tennessee                51
# Massachusetts            51
# North Carolina           51
# Florida                  51
# Alabama                  51
# Rhode Island             51
# Wisconsin                51
# Nebraska                 51
# Alaska                   51
# Virginia                 51
# New Jersey               51
# Arkansas                 34
# Nevada                   34
# Vermont                  34
# Kansas                   34
# Indiana                  34
# Delaware                 34
# Iowa                     34
# Maine                    34
# District of Columbia     34
# New Mexico               34
# Utah                     34
# South Carolina           34
# North Dakota             34
# West Virginia            34
# Montana                  34
# Oregon                   17
# Idaho                    17
# New Hampshire            17
# Mississippi              17
# South Dakota             17
# Hawaii                   17
# Wyoming                  17
# Name: StateName, dtype: int64

# %%
pensions_2017 = pensions.loc[pensions['fy'] == 2017,]

# %%
pensions_2017.head()
# Out:
#     ppd_id               PlanName    fy  system_id  \
# 16       1            Alabama ERS  2017        1.0
# 33       2       Alabama Teachers  2017        1.0
# 50       3            Alaska PERS  2017        2.0
# 67       4        Alaska Teachers  2017        3.0
# 84       5  Arizona Public Safety  2017        4.0
#
#                                          PlanFullName source_PlanBasics  \
# 16            Employees’ Retirement System of Alabama               NaN
# 33             Teachers' Retirement System of Alabama               NaN
# 50  State of Alaska Public Employees’ Retirement S...               NaN
# 67        State of Alaska Teachers’ Retirement System               NaN
# 84  Arizona Public Safety Personnel Retirement System               NaN
#
#     InPFS  FiscalYearType  PlanInceptionYear  PlanClosed  ...  HFTotal_Trgt  \
# 16    1.0             1.0             1945.0         0.0  ...           NaN
# 33    1.0             1.0             1939.0         0.0  ...           NaN
# 50    1.0             1.0             1961.0         1.0  ...          0.07
# 67    1.0             1.0             1955.0         1.0  ...          0.07
# 84    1.0             1.0             1968.0         0.0  ...          0.32
#
#     COMDTotal_Rtrn  COMDTotal_Actl COMDTotal_Trgt CashTotal_Rtrn  \
# 16             NaN             NaN            NaN            NaN
# 33             NaN             NaN            NaN            NaN
# 50          0.1138          0.0384           0.05         0.0079
# 67          0.1138          0.0384           0.05         0.0080
# 84          0.1209          0.1010           0.09         0.0232
#
#    CashTotal_Actl  CashTotal_Trgt OtherTotal_Rtrn  OtherTotal_Actl  \
# 16            NaN            0.03             NaN              NaN
# 33            NaN            0.03             NaN              NaN
# 50         0.0196            0.01             NaN              NaN
# 67         0.0195            0.01             NaN              NaN
# 84         0.0187            0.02             NaN              NaN
#
#    OtherTotal_Trgt
# 16             NaN
# 33             NaN
# 50             NaN
# 67             NaN
# 84             NaN
#
# [5 rows x 269 columns]

# %%
len(pensions_2017)
# Out:
# 178

# %%
plt.hist(pensions_2017['ActLiabilities_GASB'])
plt.show()
# Out:
# /usr/local/lib/python3.7/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.7/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
plt.boxplot(pensions_2017['ActLiabilities_GASB'])
plt.show()
# Out:
# /usr/local/lib/python3.7/site-packages/numpy/lib/function_base.py:3826: RuntimeWarning: Invalid value encountered in percentile
#   interpolation=interpolation)
# /usr/local/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1246: RuntimeWarning: invalid value encountered in less_equal
#   wiskhi = np.compress(x <= hival, x)
# /usr/local/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1253: RuntimeWarning: invalid value encountered in greater_equal
#   wisklo = np.compress(x >= loval, x)
# /usr/local/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1261: RuntimeWarning: invalid value encountered in less
#   np.compress(x < stats['whislo'], x),
# /usr/local/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1262: RuntimeWarning: invalid value encountered in greater
#   np.compress(x > stats['whishi'], x)

# %%
pensions_2017_clean = pensions_2017.dropna(subset=['ActLiabilities_GASB'])

# %%
pensions_2017_clean
# Out:
#       ppd_id                                  PlanName    fy  system_id  \
# 16         1                               Alabama ERS  2017        1.0
# 33         2                          Alabama Teachers  2017        1.0
# 50         3                               Alaska PERS  2017        2.0
# 67         4                           Alaska Teachers  2017        3.0
# 84         5                     Arizona Public Safety  2017        4.0
# 101        6                               Arizona SRS  2017        5.0
# 118        7                             Arkansas PERS  2017        6.0
# 169       10                       California Teachers  2017        9.0
# 186       11                          Chicago Teachers  2017       10.0
# 203       12                                Austin ERS  2017       11.0
# 220       13                        Colorado Municipal  2017       12.0
# 237       14                           Colorado School  2017       12.0
# 254       15                            Colorado State  2017       12.0
# 271       16                          Connecticut SERS  2017       13.0
# 322       19                          DC Police & Fire  2017       16.0
# 339       20                               DC Teachers  2017       16.0
# 356       21                  Delaware State Employees  2017       17.0
# 390       23                            Denver Schools  2017       19.0
# 421       25                    Fairfax County Schools  2017       21.0
# 438       26                                Florida RS  2017       22.0
# 455       27                               Georgia ERS  2017       23.0
# 472       28                          Georgia Teachers  2017       24.0
# 489       29                                Hawaii ERS  2017       25.0
# 523       31                                Idaho PERS  2017       27.0
# 540       32                        Illinois Municipal  2017       28.0
# 557       33                             Illinois SERS  2017       29.0
# 574       34                         Illinois Teachers  2017       30.0
# 591       35                     Illinois Universities  2017       31.0
# 608       36                              Indiana PERF  2017       32.0
# 625       37                          Indiana Teachers  2017       33.0
# ...      ...                                       ...   ...        ...
# 2376     143                     Sacramento County ERS  2017      116.0
# 2393     144                        San Diego City ERS  2017      117.0
# 2410     145                         Chicago Municipal  2017      118.0
# 2427     146                            Chicago Police  2017      119.0
# 2444     147                           Cook County ERS  2017      120.0
# 2512     151                        Milwaukee City ERS  2017      124.0
# 2529     152                    Philadelphia Municipal  2017      125.0
# 2563     154                   Detroit Police and Fire  2017      130.0
# 2580     155                 Baltimore Fire and Police  2017      131.0
# 2597     156                               Seattle ERS  2017      132.0
# 2614     158                    Nashville-Davidson ERS  2017      134.0
# 2631     159                          Jacksonville ERS  2017      135.0
# 2648     160                            Cincinatti ERS  2017      136.0
# 2665     161                               Atlanta ERS  2017      137.0
# 2682     162                              Omaha School  2017      138.0
# 2699     163                Baton Rouge City Parish RS  2017      139.0
# 2716     164                        Fairfax County ERS  2017      140.0
# 2733     165                        Detroit General RS  2017      141.0
# 2750     166            Montgomery County Maryland ERS  2017      142.0
# 2784     168                     Miami Fire and Police  2017      144.0
# 2818     170                             Hartford MERF  2017      146.0
# 2835     171                            Birmingham RRS  2017      147.0
# 2869     173                            Atlanta Police  2017      149.0
# 2890     175                  Kansas City Missouri ERS  2017      150.0
# 2907     176                    Tucson Supplemental RS  2017      151.0
# 2924     177  Lexington-Fayette County Police and Fire  2017      152.0
# 2958     179                               Wichita ERS  2017      154.0
# 2975     180                           New Orleans ERS  2017      155.0
# 2992     181                 New Castle County Pension  2017      156.0
# 3009     182                Charlotte Firefighters' RS  2017      157.0
#
#                                            PlanFullName   source_PlanBasics  \
# 16              Employees’ Retirement System of Alabama                 NaN
# 33               Teachers' Retirement System of Alabama                 NaN
# 50    State of Alaska Public Employees’ Retirement S...                 NaN
# 67          State of Alaska Teachers’ Retirement System                 NaN
# 84    Arizona Public Safety Personnel Retirement System                 NaN
# 101                     Arizona State Retirement System                 NaN
# 118         Arkansas Public Employees Retirement System                 NaN
# 169        California State Teachers’ Retirement System                 NaN
# 186   Public School Teachers' Pension and Retirement...                 NaN
# 203         City of Austin Employees' Retirement System                 NaN
# 220   Colorado Public Employee Retirement Associatio...                 NaN
# 237   Colorado Public Employee Retirement Associatio...                 NaN
# 254   Colorado Public Employee Retirement Associatio...                 NaN
# 271       Connecticut State Employees Retirement System                 NaN
# 322   District of Columbia Police Officers’ & Firefi...                 NaN
# 339      District of Columbia Teachers’ Retirement Plan                 NaN
# 356              Delaware State Employees' Pension Plan                 NaN
# 390   Colorado Public Employee Retirement Associatio...                 NaN
# 421   Educational Employees’ Supplementary Retiremen...                 NaN
# 438                           Florida Retirement System                 NaN
# 455             Employees’ Retirement System of Georgia                 NaN
# 472               Teachers Retirement System of Georgia                 NaN
# 489   Employees’ Retirement System of the State of H...                 NaN
# 523          Public Employee Retirement System of Idaho                 NaN
# 540                  Illinois Municipal Retirement Fund                 NaN
# 557      State Employees' Retirement System of Illinois                 NaN
# 574   Teachers' Retirement System of The State of Il...                 NaN
# 591    State Universities Retirement System of Illinois                 NaN
# 608   State of Indiana Public Employees' Retirement ...                 NaN
# 625             Indiana State Teachers’ Retirement Fund                 NaN
# ...                                                 ...                 ...
# 2376     Sacramento County Employees' Retirement System       2012 CAFR p 8
# 2393        San Diego City Employees' Retirement System       2012 CAFR p 8
# 2410  Chicago Municipal Employees' Annuity Benefit Fund       2012 CAFR p 9
# 2427           Chicago Policemen's Annuity Benefit Fund       2012 CAFR p 6
# 2444        Cook County Employees' Annuity Benefit Fund   2012 CAFR p 12/32
# 2512        Milwaukee City Employees' Retirement System        2012 AV p 45
# 2529           Philadelphia Municipal Retirement System      2011 CAFR p 12
# 2563          Detroit Police and Fire Retirement System  2014 CAFR p 7 p 53
# 2580  Baltimore Fire and Police Employees' Retiremen...                 NaN
# 2597               Seattle Employees' Retirement System                 NaN
# 2614  Nashville Davidson Metropolitan Employee Benef...                 NaN
# 2631     Jacksonville General Employees Retirement Plan                 NaN
# 2648            Cincinnati Employees' Retirement System                 NaN
# 2665            Atlanta General Employees' Pension Fund                 NaN
# 2682          Omaha School Employees' Retirement System                 NaN
# 2699  Baton Rouge City Parish Employees' Retirement ...                 NaN
# 2716        Fairfax County Employees' Retirement System                 NaN
# 2733                  Detroit General Retirement System                 NaN
# 2750  Montgomery County (MD) Employees' Retirement S...                 NaN
# 2784  Miami Firefighters' and Police Officers' Retir...                 NaN
# 2818      Hartford Municipal Employees' Retirement Fund                 NaN
# 2835              Birmingham Retirement & Relief System                 NaN
# 2869              Atlanta Police Officers' Pension Fund                 NaN
# 2890  Kansas City Missouri Employees' Retirement System                 NaN
# 2907              Tucson Supplemental Retirement System                 NaN
# 2924  Lexington-Fayette County Policemen's and Firef...                 NaN
# 2958               Wichita Employees' Retirement System                 NaN
# 2975           New Orleans Employees' Retirement System                 NaN
# 2992                  New Castle County Pension Program                 NaN
# 3009          Charlotte Firefighters' Retirement System                 NaN
#
#       InPFS  FiscalYearType  PlanInceptionYear  PlanClosed  ...  HFTotal_Trgt  \
# 16      1.0             1.0             1945.0         0.0  ...           NaN
# 33      1.0             1.0             1939.0         0.0  ...           NaN
# 50      1.0             1.0             1961.0         1.0  ...         0.070
# 67      1.0             1.0             1955.0         1.0  ...         0.070
# 84      1.0             1.0             1968.0         0.0  ...         0.320
# 101     1.0             1.0             1953.0         0.0  ...         0.050
# 118     1.0             1.0             1957.0         0.0  ...         0.050
# 169     1.0             1.0             1913.0         0.0  ...         0.080
# 186     1.0             1.0             1895.0         0.0  ...           NaN
# 203     1.0             2.0             1941.0         0.0  ...         0.050
# 220     1.0             2.0             1931.0         0.0  ...         0.050
# 237     1.0             2.0             1931.0         0.0  ...         0.050
# 254     1.0             2.0             1931.0         0.0  ...         0.050
# 271     1.0             1.0             1939.0         0.0  ...         0.080
# 322     1.0             1.0             1979.0         0.0  ...         0.040
# 339     1.0             1.0             1979.0         0.0  ...         0.040
# 356     1.0             1.0             1970.0         0.0  ...           NaN
# 390     1.0             2.0             1945.0         0.0  ...         0.050
# 421     1.0             1.0             1973.0         0.0  ...         0.230
# 438     1.0             1.0             1970.0         0.0  ...         0.120
# 455     1.0             1.0             1949.0         0.0  ...           NaN
# 472     1.0             1.0             1943.0         0.0  ...           NaN
# 489     1.0             1.0             1926.0         0.0  ...           NaN
# 523     1.0             1.0             1963.0         0.0  ...           NaN
# 540     1.0             2.0             1941.0         0.0  ...           NaN
# 557     1.0             1.0             1944.0         0.0  ...         0.030
# 574     1.0             1.0             1939.0         0.0  ...         0.080
# 591     1.0             1.0             1941.0         0.0  ...         0.060
# 608     1.0             1.0             1945.0         0.0  ...         0.220
# 625     1.0             1.0             1921.0         0.0  ...         0.220
# ...     ...             ...                ...         ...  ...           ...
# 2376    0.0             1.0             1941.0         0.0  ...         0.100
# 2393    0.0             1.0             1927.0         0.0  ...         0.080
# 2410    0.0             2.0             1921.0         0.0  ...         0.100
# 2427    0.0             2.0             1921.0         0.0  ...         0.180
# 2444    0.0             2.0             1926.0         0.0  ...         0.040
# 2512    0.0             2.0             1938.0         0.0  ...         0.080
# 2529    0.0             1.0             1915.0         0.0  ...         0.005
# 2563    0.0             1.0             1941.0         1.0  ...         0.100
# 2580    0.0             1.0             1962.0         0.0  ...         0.050
# 2597    0.0             2.0             1929.0         0.0  ...           NaN
# 2614    0.0             1.0             1963.0         0.0  ...         0.070
# 2631    0.0             1.0                NaN         0.0  ...           NaN
# 2648    0.0             1.0             1931.0         0.0  ...         0.050
# 2665    0.0             1.0             1927.0         0.0  ...           NaN
# 2682    0.0             1.0             1951.0         0.0  ...           NaN
# 2699    0.0             2.0             1953.0         0.0  ...         0.100
# 2716    0.0             1.0             1955.0         0.0  ...         0.350
# 2733    0.0             1.0             1918.0         0.0  ...         0.220
# 2750    0.0             1.0             1965.0         0.0  ...         0.090
# 2784    0.0             1.0             1931.0         0.0  ...         0.130
# 2818    0.0             1.0             1947.0         0.0  ...           NaN
# 2835    0.0             1.0                NaN         0.0  ...         0.150
# 2869    0.0             1.0             1924.0         0.0  ...           NaN
# 2890    0.0             1.0             1962.0         0.0  ...           NaN
# 2907    0.0             1.0             1953.0         0.0  ...           NaN
# 2924    0.0             1.0             1974.0         0.0  ...         0.100
# 2958    0.0             2.0             1948.0         0.0  ...           NaN
# 2975    0.0             2.0             1947.0         0.0  ...           NaN
# 2992    0.0             1.0             1947.0         0.0  ...         0.210
# 3009    0.0             1.0             1947.0         0.0  ...           NaN
#
#       COMDTotal_Rtrn  COMDTotal_Actl COMDTotal_Trgt CashTotal_Rtrn  \
# 16               NaN             NaN            NaN            NaN
# 33               NaN             NaN            NaN            NaN
# 50          0.113800        0.038400          0.050         0.0079
# 67          0.113800        0.038400          0.050         0.0080
# 84          0.120900        0.101000          0.090         0.0232
# 101              NaN        0.015000          0.020            NaN
# 118              NaN        0.013500          0.160            NaN
# 169              NaN             NaN            NaN         0.0092
# 186         0.068000        0.024000          0.020            NaN
# 203         0.120000        0.006000          0.010         0.0140
# 220              NaN             NaN            NaN         0.0110
# 237              NaN             NaN            NaN         0.0110
# 254              NaN             NaN            NaN         0.0110
# 271              NaN             NaN            NaN         0.0096
# 322         0.098000        0.080919          0.110         0.0100
# 339         0.098000        0.080919          0.050         0.0100
# 356              NaN             NaN            NaN            NaN
# 390              NaN             NaN            NaN         0.0110
# 421              NaN             NaN            NaN            NaN
# 438              NaN             NaN            NaN         0.0062
# 455              NaN             NaN            NaN            NaN
# 472              NaN             NaN            NaN            NaN
# 489              NaN             NaN            NaN            NaN
# 523              NaN             NaN            NaN            NaN
# 540              NaN             NaN            NaN         0.0167
# 557              NaN        0.030000          0.050            NaN
# 574         0.040000        0.057000          0.065            NaN
# 591        -0.027000        0.018000          0.020            NaN
# 608        -0.067000        0.079000          0.080         0.0490
# 625        -0.067000        0.079000          0.080         0.0490
# ...              ...             ...            ...            ...
# 2376        0.085000        0.136000          0.150            NaN
# 2393             NaN             NaN            NaN            NaN
# 2410             NaN        0.100000          0.100            NaN
# 2427        0.386000        0.010200          0.060            NaN
# 2444             NaN             NaN            NaN            NaN
# 2512        0.102000        0.033000          0.030            NaN
# 2529        0.057000        0.098000          0.091            NaN
# 2563             NaN        0.147134            NaN            NaN
# 2580             NaN             NaN            NaN            NaN
# 2597             NaN             NaN            NaN            NaN
# 2614        0.065900        0.109000          0.120         0.0091
# 2631             NaN             NaN            NaN            NaN
# 2648        0.022000        0.050000          0.075            NaN
# 2665             NaN             NaN            NaN            NaN
# 2682             NaN             NaN            NaN            NaN
# 2699             NaN             NaN            NaN            NaN
# 2716             NaN             NaN            NaN            NaN
# 2733             NaN             NaN            NaN            NaN
# 2750       -0.015000        0.095000          0.065            NaN
# 2784             NaN             NaN            NaN            NaN
# 2818        0.120000        0.013000          0.050         0.0150
# 2835             NaN             NaN            NaN            NaN
# 2869             NaN             NaN            NaN            NaN
# 2890             NaN             NaN            NaN            NaN
# 2907        0.130455        0.060000          0.050         0.0000
# 2924             NaN             NaN          0.100            NaN
# 2958        0.065304        0.071100          0.080         0.0070
# 2975             NaN             NaN            NaN            NaN
# 2992             NaN             NaN            NaN            NaN
# 3009             NaN             NaN            NaN            NaN
#
#      CashTotal_Actl  CashTotal_Trgt OtherTotal_Rtrn  OtherTotal_Actl  \
# 16              NaN           0.030             NaN              NaN
# 33              NaN           0.030             NaN              NaN
# 50         0.019600           0.010             NaN              NaN
# 67         0.019500           0.010             NaN              NaN
# 84         0.018700           0.020             NaN              NaN
# 101        0.023000             NaN             NaN              NaN
# 118        0.004200             NaN             NaN              NaN
# 169        0.015000           0.020             NaN              NaN
# 186        0.035000             NaN             NaN              NaN
# 203        0.001600             NaN             NaN              NaN
# 220        0.004000           0.010             NaN              NaN
# 237        0.004000           0.010             NaN              NaN
# 254        0.004000           0.010             NaN              NaN
# 271        0.034000           0.040             NaN              NaN
# 322        0.007992             NaN             NaN              NaN
# 339        0.007992             NaN             NaN              NaN
# 356             NaN             NaN             NaN              NaN
# 390        0.004000           0.010             NaN              NaN
# 421        0.001000             NaN             NaN              NaN
# 438        0.008000           0.010             NaN              NaN
# 455             NaN             NaN             NaN              NaN
# 472             NaN             NaN             NaN              NaN
# 489             NaN             NaN             NaN              NaN
# 523        0.015000             NaN             NaN              NaN
# 540        0.016000           0.010             NaN              NaN
# 557             NaN             NaN             NaN              NaN
# 574             NaN             NaN             NaN              NaN
# 591             NaN             NaN             NaN              NaN
# 608        0.012000             NaN             NaN              NaN
# 625        0.012000             NaN             NaN              NaN
# ...             ...             ...             ...              ...
# 2376       0.026000             NaN             NaN              NaN
# 2393       0.012000             NaN             NaN              NaN
# 2410       0.040000             NaN             NaN              NaN
# 2427       0.002600             NaN             NaN              NaN
# 2444       0.030000           0.010             NaN              NaN
# 2512       0.002000           0.010             NaN              NaN
# 2529       0.012000           0.011             NaN              NaN
# 2563       0.028298           0.010             NaN         0.023677
# 2580       0.010000           0.010             NaN              NaN
# 2597            NaN             NaN             NaN              NaN
# 2614       0.022200             NaN           0.059         0.000100
# 2631            NaN           0.010             NaN              NaN
# 2648       0.010000             NaN             NaN              NaN
# 2665            NaN             NaN             NaN              NaN
# 2682            NaN             NaN             NaN         0.065780
# 2699       0.001000             NaN             NaN              NaN
# 2716            NaN             NaN             NaN              NaN
# 2733            NaN           0.010             NaN              NaN
# 2750            NaN           0.010             NaN              NaN
# 2784       0.028000             NaN             NaN              NaN
# 2818       0.034000           0.030             NaN              NaN
# 2835            NaN             NaN             NaN              NaN
# 2869            NaN             NaN             NaN              NaN
# 2890       0.014143           0.010             NaN              NaN
# 2907       0.002000             NaN             NaN              NaN
# 2924            NaN           0.020             NaN              NaN
# 2958       0.008000           0.010             NaN              NaN
# 2975            NaN             NaN             NaN              NaN
# 2992       0.057523           0.010             NaN         0.165365
# 3009       0.008900             NaN             NaN              NaN
#
#      OtherTotal_Trgt
# 16               NaN
# 33               NaN
# 50               NaN
# 67               NaN
# 84               NaN
# 101              NaN
# 118              NaN
# 169              NaN
# 186              NaN
# 203              NaN
# 220              NaN
# 237              NaN
# 254              NaN
# 271              NaN
# 322              NaN
# 339              NaN
# 356              NaN
# 390              NaN
# 421              NaN
# 438              NaN
# 455              NaN
# 472              NaN
# 489              NaN
# 523              NaN
# 540              NaN
# 557              NaN
# 574              NaN
# 591              NaN
# 608              NaN
# 625              NaN
# ...              ...
# 2376             NaN
# 2393             NaN
# 2410             NaN
# 2427             NaN
# 2444             NaN
# 2512             NaN
# 2529             NaN
# 2563             NaN
# 2580             NaN
# 2597             NaN
# 2614             NaN
# 2631             NaN
# 2648             NaN
# 2665             NaN
# 2682             NaN
# 2699             NaN
# 2716             NaN
# 2733             NaN
# 2750             NaN
# 2784             NaN
# 2818             NaN
# 2835             NaN
# 2869             NaN
# 2890             NaN
# 2907             NaN
# 2924             NaN
# 2958             NaN
# 2975             NaN
# 2992             NaN
# 3009             NaN
#
# [143 rows x 269 columns]

# %%
plt.boxplot(pensions_2017_clean['ActLiabilities_GASB'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x11a63b0b8>,
#   <matplotlib.lines.Line2D at 0x11a63b400>],
#  'caps': [<matplotlib.lines.Line2D at 0x11a63b4e0>,
#   <matplotlib.lines.Line2D at 0x11ab03390>],
#  'boxes': [<matplotlib.lines.Line2D at 0x11a63b978>],
#  'medians': [<matplotlib.lines.Line2D at 0x11ab036d8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x11ab03a20>],
#  'means': []}

# %%
plt.hist(pensions_2017_clean['ActLiabilities_GASB'], bins=20)
plt.show()

# %%
big_2017 = pensions_2017[pensions_2017['ActLiabilities_GASB'] > 150000000]

# %%
small_2017 = pensions_2017[pensions_2017['ActLiabilities_GASB'] < 150000000]

# %%
plt.hist(small_2017['ActLiabilities_GASB'])
plt.show()

# %%
big_2017['ActLiabilities_GASB']
# Out:
# 169     286950000.0
# 438     178579116.0
# 1832    181753000.0
# Name: ActLiabilities_GASB, dtype: float64

# %%
big_2017
# Out:
#       ppd_id             PlanName    fy  system_id  \
# 169       10  California Teachers  2017        9.0
# 438       26           Florida RS  2017       22.0
# 1832     108       Texas Teachers  2017       92.0
#
#                                       PlanFullName source_PlanBasics  InPFS  \
# 169   California State Teachers’ Retirement System               NaN    1.0
# 438                      Florida Retirement System               NaN    1.0
# 1832            Teacher Retirement System of Texas               NaN    1.0
#
#       FiscalYearType  PlanInceptionYear  PlanClosed  ...  HFTotal_Trgt  \
# 169              1.0             1913.0         0.0  ...          0.08
# 438              1.0             1970.0         0.0  ...          0.12
# 1832             1.0             1937.0         0.0  ...          0.13
#
#       COMDTotal_Rtrn  COMDTotal_Actl COMDTotal_Trgt CashTotal_Rtrn  \
# 169              NaN             NaN            NaN         0.0092
# 438              NaN             NaN            NaN         0.0062
# 1832          -0.045            0.04           0.05         0.0210
#
#      CashTotal_Actl  CashTotal_Trgt OtherTotal_Rtrn  OtherTotal_Actl  \
# 169           0.015            0.02             NaN              NaN
# 438           0.008            0.01             NaN              NaN
# 1832          0.006            0.01             NaN              NaN
#
#      OtherTotal_Trgt
# 169              NaN
# 438              NaN
# 1832             NaN
#
# [3 rows x 269 columns]

# %% [markdown]
# The liabilities are in thousands because CalSTRS has $287bn of liabilities as at June 2017: https://lao.ca.gov/Publications/Report/3873

# %%
pensions_2017['StateName'].value_counts()
# Out:
# California              15
# Texas                    8
# Illinois                 8
# Louisiana                7
# Missouri                 7
# New York                 7
# Colorado                 5
# Washington               5
# Michigan                 5
# Arizona                  5
# Ohio                     5
# Minnesota                5
# Pennsylvania             5
# Kentucky                 4
# Maryland                 4
# Oklahoma                 4
# Connecticut              4
# Georgia                  4
# Wisconsin                3
# Alaska                   3
# Alabama                  3
# New Jersey               3
# Rhode Island             3
# Florida                  3
# Tennessee                3
# Nebraska                 3
# Virginia                 3
# North Carolina           3
# Massachusetts            3
# Montana                  2
# Utah                     2
# Iowa                     2
# Delaware                 2
# Maine                    2
# Kansas                   2
# Nevada                   2
# Arkansas                 2
# West Virginia            2
# North Dakota             2
# Indiana                  2
# District of Columbia     2
# Vermont                  2
# New Mexico               2
# South Carolina           2
# New Hampshire            1
# Oregon                   1
# Hawaii                   1
# Idaho                    1
# Mississippi              1
# Wyoming                  1
# South Dakota             1
# Name: StateName, dtype: int64

# %%
plt.boxplot(pensions_2017['StateName'].value_counts())
plt.show()

# %%
pensions_2017['StateName'].value_counts().plot(kind='bar', figsize=(10,5))
plt.ylabel("Number of pension schemes")
plt.title("Number of pensions schemes by state in 2017")
plt.show()

# %%
num_yrs = pensions.PlanName.value_counts()
print(num_yrs.head())
# Out:
# Denver Employees                17
# Florida RS                      17
# Rhode Island ERS                17
# Washington Teachers Plan 2/3    17
# Chicago Municipal               17
# Name: PlanName, dtype: int64

# %%
len(num_yrs)
# Out:
# 180

# %%
count_num_yrs = num_yrs.value_counts()

# %%
print(count_num_yrs.head())
# Out:
# 17    178
# 14      1
# 4       1
# Name: PlanName, dtype: int64

# %%
plt.pie(count_num_yrs)
plt.title("Years of data held for each scheme")
plt.legend(["17 years", "14 years", "4 years"], loc='lower right')
plt.show()

# %%
pensions_2001 = pensions[pensions['fy'] == 2001]

# %%
len(pensions_2001)
# Out:
# 180

# %%
pensions_2001_clean = pensions_2001.dropna(subset = ['ActLiabilities_GASB'])

# %%
plt.boxplot([pensions_2001_clean['ActLiabilities_GASB'], pensions_2017_clean['ActLiabilities_GASB']])
plt.show()

# %%
plt.boxplot([pensions_2001.dropna(subset=['ActFundedRatio_GASB'])['ActFundedRatio_GASB'], pensions_2017.dropna(subset=['ActFundedRatio_GASB'])['ActFundedRatio_GASB']])
plt.title("Funding ratios of schemes in 2001 and 2017")
plt.xticks([1, 2], ["2001", "2017"])
plt.ylabel("Funding ratio")
plt.show()

# %%
plt.hist(pensions_2001.dropna(subset=['ActFundedRatio_GASB'])['ActFundedRatio_GASB'], color='orange', alpha=.5, density=True)
plt.hist(pensions_2017.dropna(subset=['ActFundedRatio_GASB'])['ActFundedRatio_GASB'], color='blue', alpha=0.5, density=True)
plt.title("Funding ratios of schemes in 2001 and 2017")
plt.legend(["2001", "2017"])
plt.ylabel("Funding ratio")
plt.show()

# %%
years = [2001, 2017]
pensions_test = pensions[pensions.fy.isin(years)]

# %%
pensions_test = pensions_test.dropna(subset = ['ActLiabilities_GASB'])

# %%
counts = pd.DataFrame(pensions_test.PlanName.value_counts())
counts.head()
# Out:
#                           PlanName
# Massachusetts SRS                2
# Wyoming Public Employees         2
# Maryland Teachers                2
# Arizona SRS                      2
# Louisiana Teachers               2

# %%
in_both = counts[counts['PlanName'] > 1]

# %%
in_both_list = list(in_both.index)

# %%
type(in_both_list)
# Out:
# list

# %%
pensions_01_17 = pensions_test[pensions_test.PlanName.isin(in_both_list)]

# %%
pensions_01 = pensions_01_17[pensions_01_17['fy'] == 2001]
pensions_17 = pensions_01_17[pensions_01_17['fy'] == 2017]
liabs_01 = pd.DataFrame(pensions_01.groupby('StateAbbrev')['ActLiabilities_GASB'].sum())
liabs_17 = pd.DataFrame(pensions_17.groupby('StateAbbrev')['ActLiabilities_GASB'].sum())
liabs_01_17 = pd.DataFrame(index = liabs_01.index)
liabs_01_17['Liabs_2001'] = liabs_01['ActLiabilities_GASB'] / 1000000 #Change to billions
liabs_01_17['Liabs_2017'] = liabs_17['ActLiabilities_GASB'] / 1000000 #Originally in thousands
liabs_01_17
# Out:
#              Liabs_2001  Liabs_2017
# StateAbbrev
# AK             9.179514   21.049655
# AL            25.976100   53.361889
# AR             4.111000   10.510000
# AZ            24.996068   76.558220
# CA           213.063733  572.457072
# CO             4.297317    9.134458
# CT            12.970936   34.518970
# DE             4.502757   10.641313
# FL            83.390247  183.317823
# GA            49.251885  114.861318
# HI            10.506913   28.648600
# IA            16.827787   40.463753
# ID             6.679100   17.063300
# IL           111.910383  321.726019
# IN            21.829498   42.757221
# KS            11.493172   28.788734
# KY            25.651411   67.933165
# LA            29.307263   60.383817
# MA            33.340000   87.510222
# MD            35.125599   73.701755
# ME             9.425022   16.501547
# MI            56.294850  101.731855
# MN            39.355805   78.362990
# MO            35.230794   76.349872
# MS            18.494207   43.166491
# NC             0.254767    0.604169
# ND             2.476400    7.460832
# NE             2.601600   14.602525
# NH             3.842602   13.208449
# NJ            74.373446  157.939428
# NM            15.953747   40.065396
# NV            16.664176   51.986097
# NY            69.836237  115.672500
# OH           117.499659  220.260346
# OK            19.224732   34.238838
# OR            43.350500   80.970300
# PA            77.909457  161.563896
# RI             8.526626   13.506855
# SC            23.486404   55.484337
# SD             4.688400   11.634963
# TN             1.628957    3.091309
# TX           123.487623  288.931512
# VA            38.794360   98.251519
# VT             2.281334    5.793418
# WI            63.226211  106.639062
# WV             8.366863   17.559736
# WY             4.442033    9.588653

# %%
# Plot scatter
x=liabs_01_17['Liabs_2001']
y=liabs_01_17['Liabs_2017']
labels = list(liabs_01_17.index)
plt.scatter(x, y)
plt.xlim([0, 300])
plt.xlabel("Liabilities in 2001 ($billions)")
plt.ylabel("Liabilities in 2017 ($billions)")
plt.title("Pension liabilities by state")

for i, txt in enumerate(labels):
    plt.annotate(s=txt, xy=(x[i], y[i]))
plt.show()

# %%
# Find change in liabilities and plot
liabs_01_17['Liabs_change'] = liabs_01_17['Liabs_2017'] - liabs_01_17['Liabs_2001']
liabs_01_17.Liabs_change.plot(kind='bar', figsize=(15,5))
plt.title("Change in liabilities between 2001 and 2017")
plt.ylabel("Increase in liabilities ($billions)")
plt.xlabel("State")
plt.show()

# %%
liabs_01_17['Liabs_change']
# Out:
# StateAbbrev
# AK     11.870141
# AL     27.385790
# AR      6.399000
# AZ     51.562152
# CA    359.393339
# CO      4.837141
# CT     21.548034
# DE      6.138556
# FL     99.927576
# GA     65.609433
# HI     18.141687
# IA     23.635966
# ID     10.384200
# IL    209.815636
# IN     20.927723
# KS     17.295562
# KY     42.281754
# LA     31.076554
# MA     54.170222
# MD     38.576156
# ME      7.076526
# MI     45.437006
# MN     39.007185
# MO     41.119077
# MS     24.672284
# NC      0.349402
# ND      4.984432
# NE     12.000924
# NH      9.365847
# NJ     83.565982
# NM     24.111649
# NV     35.321922
# NY     45.836263
# OH    102.760687
# OK     15.014106
# OR     37.619800
# PA     83.654439
# RI      4.980229
# SC     31.997933
# SD      6.946563
# TN      1.462353
# TX    165.443889
# VA     59.457159
# VT      3.512084
# WI     43.412851
# WV      9.192873
# WY      5.146620
# Name: Liabs_change, dtype: float64

# %%
num_schemes = pd.DataFrame(pensions_17.StateAbbrev.value_counts())

# %%
num_schemes.sort_index(inplace=True)

# %%
liabs_01_17['Num_schemes'] = num_schemes['StateAbbrev']

# %%
liabs_01_17
# Out:
#              Liabs_2001  Liabs_2017  Liabs_change  Num_schemes
# StateAbbrev
# AK             9.179514   21.049655     11.870141            2
# AL            25.976100   53.361889     27.385790            3
# AR             4.111000   10.510000      6.399000            1
# AZ            24.996068   76.558220     51.562152            5
# CA           213.063733  572.457072    359.393339           13
# CO             4.297317    9.134458      4.837141            2
# CT            12.970936   34.518970     21.548034            2
# DE             4.502757   10.641313      6.138556            2
# FL            83.390247  183.317823     99.927576            3
# GA            49.251885  114.861318     65.609433            3
# HI            10.506913   28.648600     18.141687            1
# IA            16.827787   40.463753     23.635966            2
# ID             6.679100   17.063300     10.384200            1
# IL           111.910383  321.726019    209.815636            8
# IN            21.829498   42.757221     20.927723            2
# KS            11.493172   28.788734     17.295562            2
# KY            25.651411   67.933165     42.281754            4
# LA            29.307263   60.383817     31.076554            7
# MA            33.340000   87.510222     54.170222            2
# MD            35.125599   73.701755     38.576156            4
# ME             9.425022   16.501547      7.076526            2
# MI            56.294850  101.731855     45.437006            4
# MN            39.355805   78.362990     39.007185            5
# MO            35.230794   76.349872     41.119077            7
# MS            18.494207   43.166491     24.672284            1
# NC             0.254767    0.604169      0.349402            1
# ND             2.476400    7.460832      4.984432            2
# NE             2.601600   14.602525     12.000924            2
# NH             3.842602   13.208449      9.365847            1
# NJ            74.373446  157.939428     83.565982            3
# NM            15.953747   40.065396     24.111649            2
# NV            16.664176   51.986097     35.321922            2
# NY            69.836237  115.672500     45.836263            1
# OH           117.499659  220.260346    102.760687            4
# OK            19.224732   34.238838     15.014106            3
# OR            43.350500   80.970300     37.619800            1
# PA            77.909457  161.563896     83.654439            3
# RI             8.526626   13.506855      4.980229            2
# SC            23.486404   55.484337     31.997933            2
# SD             4.688400   11.634963      6.946563            1
# TN             1.628957    3.091309      1.462353            1
# TX           123.487623  288.931512    165.443889            6
# VA            38.794360   98.251519     59.457159            3
# VT             2.281334    5.793418      3.512084            2
# WI            63.226211  106.639062     43.412851            2
# WV             8.366863   17.559736      9.192873            2
# WY             4.442033    9.588653      5.146620            1

# %%
deficits = pensions.loc[:, ['PlanName', 'fy', 'StateAbbrev', 'UAAL_GASB']]

# %%
deficits.loc[:20, :]
# Out:
#             PlanName    fy StateAbbrev    UAAL_GASB
# 0        Alabama ERS  2001          AL   -18348.000
# 1        Alabama ERS  2002          AL   392623.000
# 2        Alabama ERS  2003          AL   811779.000
# 3        Alabama ERS  2004          AL   982533.000
# 4        Alabama ERS  2005          AL  1699618.000
# 5        Alabama ERS  2006          AL  2170033.000
# 6        Alabama ERS  2007          AL  2599445.000
# 7        Alabama ERS  2008          AL  3172921.000
# 8        Alabama ERS  2009          AL  3828072.000
# 9        Alabama ERS  2010          AL  4544788.000
# 10       Alabama ERS  2011          AL  4910638.000
# 11       Alabama ERS  2012          AL  4768444.000
# 12       Alabama ERS  2013          AL  4990141.000
# 13       Alabama ERS  2014          AL  5003713.000
# 14       Alabama ERS  2015          AL  5134462.000
# 15       Alabama ERS  2016          AL  5645728.918
# 16       Alabama ERS  2017          AL  5559883.000
# 17  Alabama Teachers  2001          AL  -236682.000
# 18  Alabama Teachers  2002          AL   469293.000
# 19  Alabama Teachers  2003          AL  1247265.000
# 20  Alabama Teachers  2004          AL  2182181.000

# %%
test = deficits.pivot(index='PlanName', columns='fy', values='UAAL_GASB')

# %%
test.head()
# Out:
# fy                      2001       2002       2003       2004       2005  \
# PlanName
# Alabama ERS         -18348.0   392623.0   811779.0   982533.0  1699618.0
# Alabama Teachers   -236682.0   469293.0  1247265.0  2182181.0  3779131.0
# Alameda County ERS -181578.0   265560.0   508286.0   778205.0   766370.0
# Alaska PERS         -51414.0  1522012.0  1722868.0  2001915.0  2428778.0
# Alaska Teachers     183178.0  1260513.0  1496185.0  1568703.0  1693943.0
#
# fy                       2006       2007       2008       2009       2010  \
# PlanName
# Alabama ERS         2170033.0  2599445.0  3172921.0  3828072.0  4544788.0
# Alabama Teachers    4123967.0  5320618.0  5991640.0  6955052.0  8166744.0
# Alameda County ERS   697316.0   552190.0   893909.0  1110331.0  1386612.0
# Alaska PERS         1762978.0  1923320.0  1943510.0  3593558.0  3901840.0
# Alaska Teachers     1562402.0  1601581.0  1561568.0  2348268.0  2747113.0
#
# fy                       2011       2012        2013        2014        2015  \
# PlanName
# Alabama ERS         4910638.0  4768444.0   4990141.0   5003713.0   5134462.0
# Alabama Teachers    9346181.0  9465359.0  10036027.0  10027958.0  10104563.0
# Alameda County ERS  1490794.0  1729057.0   1650743.0   1910975.0   1791484.0
# Alaska PERS         4156898.0  4898523.0   5435132.0   5216321.0   4406769.0
# Alaska Teachers     2850155.0  3204783.0   3419240.0   3150223.0   1629073.0
#
# fy                          2016        2017
# PlanName
# Alabama ERS         5.645729e+06   5559883.0
# Alabama Teachers    1.049832e+07  10801001.0
# Alameda County ERS  1.801577e+06   2156682.0
# Alaska PERS         4.576371e+06   4602427.0
# Alaska Teachers     1.731101e+06   1740690.0

# %%
test_2 = pd.DataFrame(index=deficits.index)
test_2['PlanName'] = deficits.loc[:, 'PlanName']
test_2['StateAbbrev'] = deficits.loc[:, 'StateAbbrev']
test_2 = test_2.drop_duplicates()
test_2.sort_values('PlanName', inplace=True)

# %%
test_2.index = test_2.PlanName

# %%
test.loc['Total'] = test.sum()

# %%
test.iloc[ 1:10, 1:5 ]
# Out:
# fy                                         2002         2003         2004  \
# PlanName
# Alabama Teachers                     469293.000  1247265.000  2182181.000
# Alameda County ERS                   265560.000   508286.000   778205.000
# Alaska PERS                         1522012.000  1722868.000  2001915.000
# Alaska Teachers                     1260513.000  1496185.000  1568703.000
# Anchorage Police and Fire                   NaN   -12715.000   -24743.000
# Arizona Public Safety               -540175.000   -41764.000   393020.000
# Arizona SRS                        -1357000.000   363000.000  1847000.000
# Arizona State Corrections Officers  -150208.099  -102493.295   -37846.132
# Arkansas PERS                         -6000.000   258000.000   567000.000
#
# fy                                         2005
# PlanName
# Alabama Teachers                    3779131.000
# Alameda County ERS                   766370.000
# Alaska PERS                         2428778.000
# Alaska Teachers                     1693943.000
# Anchorage Police and Fire            -24129.000
# Arizona Public Safety               1064974.000
# Arizona SRS                         3678000.000
# Arizona State Corrections Officers    33044.123
# Arkansas PERS                        739000.000

# %%
test2 = test.T
test2.head()
# Out:
# PlanName  Alabama ERS  Alabama Teachers  Alameda County ERS  Alaska PERS  \
# fy
# 2001         -18348.0         -236682.0           -181578.0     -51414.0
# 2002         392623.0          469293.0            265560.0    1522012.0
# 2003         811779.0         1247265.0            508286.0    1722868.0
# 2004         982533.0         2182181.0            778205.0    2001915.0
# 2005        1699618.0         3779131.0            766370.0    2428778.0
#
# PlanName  Alaska Teachers  Anchorage Police and Fire  Arizona Public Safety  \
# fy
# 2001             183178.0                        NaN              -987183.0
# 2002            1260513.0                        NaN              -540175.0
# 2003            1496185.0                   -12715.0               -41764.0
# 2004            1568703.0                   -24743.0               393020.0
# 2005            1693943.0                   -24129.0              1064974.0
#
# PlanName  Arizona SRS  Arizona State Corrections Officers  Arkansas PERS  ...  \
# fy                                                                        ...
# 2001       -2876000.0                         -221790.354      -231000.0  ...
# 2002       -1357000.0                         -150208.099        -6000.0  ...
# 2003         363000.0                         -102493.295       258000.0  ...
# 2004        1847000.0                          -37846.132       567000.0  ...
# 2005        3678000.0                           33044.123       739000.0  ...
#
# PlanName  Washington LEOFF Plan 2  Washington PERS 2/3  \
# fy
# 2001                    -907600.0           -4873600.0
# 2002                    -709000.0           -3923800.0
# 2003                    -546400.0           -3236300.0
# 2004                    -426300.0           -2927100.0
# 2005                    -397100.0           -2611000.0
#
# PlanName  Washington School Employees Plan 2/3  Washington Teachers Plan 2/3  \
# fy
# 2001                                 -724700.0                    -1750200.0
# 2002                                 -620000.0                    -1715200.0
# 2003                                 -495000.0                    -1535000.0
# 2004                                 -439000.0                    -1427100.0
# 2005                                 -314400.0                    -1131200.0
#
# PlanName  West Virginia PERS  West Virginia Teachers  Wichita ERS  \
# fy
# 2001                496642.0               4098163.0     -75046.0
# 2002                843690.0               4610560.0     -62967.0
# 2003                991060.0               5052596.0     -59757.0
# 2004                774541.0               5013263.0     -49835.0
# 2005                669734.0               4990353.0     -45978.0
#
# PlanName  Wisconsin RS  Wyoming Public Employees         Total
# fy
# 2001         2110400.0               -140429.306 -8.771259e+07
# 2002         1756900.0                366194.198  2.370365e+08
# 2003          526400.0                419545.375  5.324758e+08
# 2004          412900.0                198022.676  6.589167e+08
# 2005          363500.0                247901.886  8.083650e+08
#
# [5 rows x 181 columns]

# %%
plt.plot(test2['Total'])
plt.show()
